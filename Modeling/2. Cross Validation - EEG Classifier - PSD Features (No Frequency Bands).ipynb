# %% [markdown]
# # Classifier Model with PSD Features from EEG Data without using Frequency Bands

# %% [markdown]
# **Description**:\
# Develop a prediction model with the training dataset obtained with the PSD Method from MNE. The objective is to evaluate different classifier models and measure the results to compare them between the training dataset with all channels and only frontopolar channels.
#
# For this section, all the dataset required are stored in the Training Dataset directory, which are mainly the PSD Feature Extraction results. For futher understanding, you can take a look at the notebook [Feature Extraction PSD no Freq-Bands](https://github.com/sobieddch90/mcd-udg-tfm-eeg-classification/blob/main/Modeling/2.%20EEG%20Classifier%20-%20PSD%20Features%20no%20Freq-Bands.ipynb) in Feature Extraction the `Feature Extraction` directory.
#
# **Author**: Elmo Chavez\
# **Date**: November 25, 2023

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import os
import sys

path_eeg_mne = os.path.abspath(os.path.join(os.path.dirname('eeg_mne.py'), '..'))
sys.path.append(path_eeg_mne)
import eeg_mne

# %% [markdown]
# ## Read the Dataset

# %%
path_training = '../Training Dataset/'

# Participants Dataset preselected in Feature Extraction step 1
file_participants_selected = 'Participants_Selected.csv'
df_participants_selected = pd.read_csv(path_training+file_participants_selected)

# PSD features with All channel
file_psd_features_all = 'PSD_Features-All_Channels_no_FreqBands.csv'
df_features_all = pd.read_csv(path_training+file_psd_features_all)

# PSD features with only FP1 channel
file_psd_features_fp1 = 'PSD_Features-FP1_Channel_no_FreqBands.csv'
df_features_fp1 = pd.read_csv(path_training+file_psd_features_fp1)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# **Brief Summary about the Participants Selected**

# %%
df_participants_selected
# Out:
#    participant_id  Gender  Age  Group  MMSE  time_max  points  sfreq   flag
# 0         sub-001       0   57      0    16   599.798  299900  500.0   True
# 1         sub-002       0   78      0    22   793.098  396550  500.0   True
# 2         sub-003       1   70      0    14   306.098  153050  500.0  False
# 3         sub-004       0   67      0    20   706.098  353050  500.0   True
# 4         sub-005       1   70      0    22   804.098  402050  500.0   True
# ..            ...     ...  ...    ...   ...       ...     ...    ...    ...
# 83        sub-084       0   71      1    24   652.098  326050  500.0   True
# 84        sub-085       1   64      1    26   560.058  280030  500.0   True
# 85        sub-086       1   49      1    26   578.798  289400  500.0   True
# 86        sub-087       1   73      1    24   602.758  301380  500.0   True
# 87        sub-088       1   55      1    24   784.698  392350  500.0   True
#
# [88 rows x 9 columns]

# %% [markdown]
# Remove Participants not flagged:\
#     - Participants with Healthy Control\
#     - Participants with maximum recorded time less than 540 seconds\
#     - Balancing classes to 22 samples for each group (Alzheimer Disease and Frototemporal Dementia)

# %%
df_participants_selected = df_participants_selected[df_participants_selected['flag']==True].reset_index(drop=True)
df_participants_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   participant_id  44 non-null     object
#  1   Gender          44 non-null     int64
#  2   Age             44 non-null     int64
#  3   Group           44 non-null     int64
#  4   MMSE            44 non-null     int64
#  5   time_max        44 non-null     float64
#  6   points          44 non-null     int64
#  7   sfreq           44 non-null     float64
#  8   flag            44 non-null     bool
# dtypes: bool(1), float64(2), int64(5), object(1)
# memory usage: 2.9+ KB

# %%
df_participants_selected.groupby('Group')['participant_id'].count()
# Out:
# Group
# 0    22
# 1    22
# Name: participant_id, dtype: int64

# %% [markdown]
# **Features Extracted using PSD Method from MNE for All the Channels**

# %%
eeg_mne.Dataset_Features_Summary(df_features_all)
# Out:
# Total Features: 1049
# Windows: 11 -> ['w0', 'w1', 'w10', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9']
# Channels: 19 -> ['Cz', 'Fp1', 'O2', 'C3', 'F4', 'T5', 'T6', 'Fz', 'F3', 'T4', 'Fp2', 'P4', 'F7', 'O1', 'T3', 'C4', 'Pz', 'P3', 'F8']
# Frequency Bands: 5 -> ['std', 'average', 'spectral', 'total', 'peak']
# Features: 5 -> ['power', 'dev', 'v', 'entropy', 'to peak']

# %% [markdown]
# **Features Extracted using PSD Method from MNE for the _FP1_ Channel**

# %%
eeg_mne.Dataset_Features_Summary(df_features_fp1)
# Out:
# Total Features: 59
# Windows: 11 -> ['w0', 'w1', 'w10', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9']
# Channels: 1 -> ['Fp1']
# Frequency Bands: 5 -> ['std', 'average', 'spectral', 'total', 'peak']
# Features: 4 -> ['power', 'dev', 'entropy', 'to peak']

# %% [markdown]
# ## Predictions with Cross-Validation

# %% [markdown]
# ### All Channels

# %%
df_results_cv_allch = eeg_mne.eeg_classifier_cv(df=df_features_all, feature_id='participant_id', target='Group', feature_extraction='PSD', channels='All')
df_results_cv_allch.head(10)
# Out:
# Running: Support Vector
# Running: Random Forest
# Running: XGBoost
# Running: LigthGBM
# Running: AdaBoost
#   feature_extraction channels      classifier        cross-validation  \
# 0                PSD      All  Support Vector                   KFold
# 1                PSD      All  Support Vector                   KFold
# 2                PSD      All  Support Vector                   KFold
# 3                PSD      All  Support Vector         StratifiedKFold
# 4                PSD      All  Support Vector         StratifiedKFold
# 5                PSD      All  Support Vector         StratifiedKFold
# 6                PSD      All  Support Vector  StratifiedShuffleSplit
# 7                PSD      All  Support Vector  StratifiedShuffleSplit
# 8                PSD      All  Support Vector  StratifiedShuffleSplit
# 9                PSD      All   Random Forest                   KFold
#
#      feature-selection  accuracy  f1_score    AUC
# 0                anova  0.519444  0.487532  0.520
# 1  mutual_info_classif  0.386111  0.277622  0.475
# 2                 chi2  0.461111  0.369744  0.550
# 3                anova  0.427778  0.377772  0.445
# 4  mutual_info_classif  0.500000  0.437900  0.525
# 5                 chi2  0.480556  0.358881  0.525
# 6                anova  0.533333  0.497989  0.540
# 7  mutual_info_classif  0.488889  0.379487  0.535
# 8                 chi2  0.444444  0.307692  0.500
# 9                anova  0.411111  0.289744  0.500

# %% [markdown]
# Show the Top 20 results

# %%
df_results_cv_allch.sort_values('AUC',ascending=False).head(20)
# Out:
#    feature_extraction channels      classifier        cross-validation  \
# 11                PSD      All   Random Forest                   KFold
# 24                PSD      All         XGBoost  StratifiedShuffleSplit
# 2                 PSD      All  Support Vector                   KFold
# 6                 PSD      All  Support Vector  StratifiedShuffleSplit
# 17                PSD      All   Random Forest  StratifiedShuffleSplit
# 7                 PSD      All  Support Vector  StratifiedShuffleSplit
# 18                PSD      All         XGBoost                   KFold
# 25                PSD      All         XGBoost  StratifiedShuffleSplit
# 4                 PSD      All  Support Vector         StratifiedKFold
# 5                 PSD      All  Support Vector         StratifiedKFold
# 0                 PSD      All  Support Vector                   KFold
# 34                PSD      All        LigthGBM  StratifiedShuffleSplit
# 35                PSD      All        LigthGBM  StratifiedShuffleSplit
# 28                PSD      All        LigthGBM                   KFold
# 27                PSD      All        LigthGBM                   KFold
# 37                PSD      All        AdaBoost                   KFold
# 29                PSD      All        LigthGBM                   KFold
# 30                PSD      All        LigthGBM         StratifiedKFold
# 31                PSD      All        LigthGBM         StratifiedKFold
# 36                PSD      All        AdaBoost                   KFold
#
#       feature-selection  accuracy  f1_score       AUC
# 11                 chi2  0.572222  0.535000  0.645000
# 24                anova  0.600000  0.576190  0.600000
# 2                  chi2  0.461111  0.369744  0.550000
# 6                 anova  0.533333  0.497989  0.540000
# 17                 chi2  0.533333  0.531111  0.540000
# 7   mutual_info_classif  0.488889  0.379487  0.535000
# 18                anova  0.563889  0.511339  0.531667
# 25  mutual_info_classif  0.533333  0.521320  0.525000
# 4   mutual_info_classif  0.500000  0.437900  0.525000
# 5                  chi2  0.480556  0.358881  0.525000
# 0                 anova  0.519444  0.487532  0.520000
# 34  mutual_info_classif  0.444444  0.307692  0.500000
# 35                 chi2  0.444444  0.307692  0.500000
# 28  mutual_info_classif  0.411111  0.289744  0.500000
# 27                anova  0.411111  0.289744  0.500000
# 37  mutual_info_classif  0.411111  0.289744  0.500000
# 29                 chi2  0.411111  0.289744  0.500000
# 30                anova  0.455556  0.312821  0.500000
# 31  mutual_info_classif  0.455556  0.312821  0.500000
# 36                anova  0.411111  0.289744  0.500000

# %% [markdown]
# ### FP1 Channel

# %%
df_results_cv_fp1 = eeg_mne.eeg_classifier_cv(df=df_features_fp1, feature_id='participant_id', target='Group', feature_extraction='PSD', channels='Fp1')
df_results_cv_fp1.head(10)
# Out:
# Running: Support Vector
# Running: Random Forest
# Running: XGBoost
# Running: LigthGBM
# Running: AdaBoost
#   feature_extraction channels      classifier        cross-validation  \
# 0                PSD      Fp1  Support Vector                   KFold
# 1                PSD      Fp1  Support Vector                   KFold
# 2                PSD      Fp1  Support Vector                   KFold
# 3                PSD      Fp1  Support Vector         StratifiedKFold
# 4                PSD      Fp1  Support Vector         StratifiedKFold
# 5                PSD      Fp1  Support Vector         StratifiedKFold
# 6                PSD      Fp1  Support Vector  StratifiedShuffleSplit
# 7                PSD      Fp1  Support Vector  StratifiedShuffleSplit
# 8                PSD      Fp1  Support Vector  StratifiedShuffleSplit
# 9                PSD      Fp1   Random Forest                   KFold
#
#      feature-selection  accuracy  f1_score       AUC
# 0                anova  0.386111  0.277622  0.475000
# 1  mutual_info_classif  0.475000  0.417532  0.551667
# 2                 chi2  0.461111  0.369744  0.550000
# 3                anova  0.380556  0.268376  0.425000
# 4  mutual_info_classif  0.494444  0.428077  0.525000
# 5                 chi2  0.480556  0.358881  0.525000
# 6                anova  0.444444  0.350849  0.470000
# 7  mutual_info_classif  0.400000  0.326538  0.425000
# 8                 chi2  0.444444  0.307692  0.500000
# 9                anova  0.366667  0.294228  0.440000

# %%
df_results_cv_fp1.sort_values('AUC',ascending=False).head(20)
# Out:
#    feature_extraction channels      classifier        cross-validation  \
# 11                PSD      Fp1   Random Forest                   KFold
# 22                PSD      Fp1         XGBoost         StratifiedKFold
# 18                PSD      Fp1         XGBoost                   KFold
# 1                 PSD      Fp1  Support Vector                   KFold
# 2                 PSD      Fp1  Support Vector                   KFold
# 17                PSD      Fp1   Random Forest  StratifiedShuffleSplit
# 4                 PSD      Fp1  Support Vector         StratifiedKFold
# 5                 PSD      Fp1  Support Vector         StratifiedKFold
# 42                PSD      Fp1        AdaBoost  StratifiedShuffleSplit
# 40                PSD      Fp1        AdaBoost         StratifiedKFold
# 16                PSD      Fp1   Random Forest  StratifiedShuffleSplit
# 32                PSD      Fp1        LigthGBM         StratifiedKFold
# 29                PSD      Fp1        LigthGBM                   KFold
# 30                PSD      Fp1        LigthGBM         StratifiedKFold
# 31                PSD      Fp1        LigthGBM         StratifiedKFold
# 34                PSD      Fp1        LigthGBM  StratifiedShuffleSplit
# 33                PSD      Fp1        LigthGBM  StratifiedShuffleSplit
# 13                PSD      Fp1   Random Forest         StratifiedKFold
# 27                PSD      Fp1        LigthGBM                   KFold
# 10                PSD      Fp1   Random Forest                   KFold
#
#       feature-selection  accuracy  f1_score       AUC
# 11                 chi2  0.547222  0.501061  0.620000
# 22  mutual_info_classif  0.563889  0.546775  0.580000
# 18                anova  0.547222  0.526912  0.555000
# 1   mutual_info_classif  0.475000  0.417532  0.551667
# 2                  chi2  0.461111  0.369744  0.550000
# 17                 chi2  0.533333  0.523117  0.540000
# 4   mutual_info_classif  0.494444  0.428077  0.525000
# 5                  chi2  0.480556  0.358881  0.525000
# 42                anova  0.488889  0.422644  0.515000
# 40  mutual_info_classif  0.477778  0.361282  0.515000
# 16  mutual_info_classif  0.466667  0.356154  0.510000
# 32                 chi2  0.455556  0.312821  0.500000
# 29                 chi2  0.411111  0.289744  0.500000
# 30                anova  0.455556  0.312821  0.500000
# 31  mutual_info_classif  0.455556  0.312821  0.500000
# 34  mutual_info_classif  0.444444  0.307692  0.500000
# 33                anova  0.444444  0.307692  0.500000
# 13  mutual_info_classif  0.455556  0.312821  0.500000
# 27                anova  0.411111  0.289744  0.500000
# 10  mutual_info_classif  0.433333  0.299634  0.500000

# %% [markdown]
# Best performance from each Classifier for the two approaches (All Channels and FP1 Channel)

# %%
df_results_cv = pd.concat([df_results_cv_allch, df_results_cv_fp1], ignore_index=True)
df_results_cv['feature_extraction'] = 'PSD without Freq-Bands'
df_results_cv_sorted = df_results_cv.sort_values('AUC',ascending=False)
df_results_cv_sorted.groupby(['channels']).head(5)
# Out:
#         feature_extraction channels      classifier        cross-validation  \
# 11  PSD without Freq-Bands      All   Random Forest                   KFold
# 56  PSD without Freq-Bands      Fp1   Random Forest                   KFold
# 24  PSD without Freq-Bands      All         XGBoost  StratifiedShuffleSplit
# 67  PSD without Freq-Bands      Fp1         XGBoost         StratifiedKFold
# 63  PSD without Freq-Bands      Fp1         XGBoost                   KFold
# 46  PSD without Freq-Bands      Fp1  Support Vector                   KFold
# 47  PSD without Freq-Bands      Fp1  Support Vector                   KFold
# 2   PSD without Freq-Bands      All  Support Vector                   KFold
# 17  PSD without Freq-Bands      All   Random Forest  StratifiedShuffleSplit
# 6   PSD without Freq-Bands      All  Support Vector  StratifiedShuffleSplit
#
#       feature-selection  accuracy  f1_score       AUC
# 11                 chi2  0.572222  0.535000  0.645000
# 56                 chi2  0.547222  0.501061  0.620000
# 24                anova  0.600000  0.576190  0.600000
# 67  mutual_info_classif  0.563889  0.546775  0.580000
# 63                anova  0.547222  0.526912  0.555000
# 46  mutual_info_classif  0.475000  0.417532  0.551667
# 47                 chi2  0.461111  0.369744  0.550000
# 2                  chi2  0.461111  0.369744  0.550000
# 17                 chi2  0.533333  0.531111  0.540000
# 6                 anova  0.533333  0.497989  0.540000

# %% [markdown]
# ## Save Results

# %%
file_results_cv = 'Results PSD no Freq-Bands - Cross-Validation.csv'
df_results_cv.to_csv(path_training+file_results_cv)
