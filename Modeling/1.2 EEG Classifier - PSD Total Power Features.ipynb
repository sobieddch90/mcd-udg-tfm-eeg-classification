# %% [markdown]
# # Classifier Model with PSD Alpha and Theta Features from EEG Data

# %% [markdown]
# **Description**:\
# Develop a prediction model with the training dataset obtained with the PSD Method from MNE, on this approach the intention is selecting only the features from the Alpha and Theta frequency bands for all the channels and windows. The objective is to evaluate different classifier models and measure the results to compare them like the work done before.
#
# For this section, all the dataset required are stored in the Training Dataset directory, which are mainly the PSD Feature Extraction results. For futher understanding, you can take a look at the notebook `Feature Extraction PSD.ipynb` in Feature Extraction the `Feature Extraction` directory.
#
# **Author**: Elmo Chavez\
# **Date**: November 20, 2023

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import os
import sys

path_eeg_mne = os.path.abspath(os.path.join(os.path.dirname('eeg_mne.py'), '..'))
sys.path.append(path_eeg_mne)
import eeg_mne

# %% [markdown]
# ## Read the Dataset

# %%
path_training = '../Training Dataset/'

# Participants Dataset preselected in Feature Extraction step 1
file_participants_selected = 'Participants_Selected.csv'
df_participants_selected = pd.read_csv(path_training+file_participants_selected)

# PSD features with only FP1 channel
file_psd_features_all = 'PSD_Features-All_Channels.csv'
df_features_all = pd.read_csv(path_training+file_psd_features_all)

# PSD features with only FP1 channel
file_psd_features_fp1 = 'PSD_Features-FP1_Channel.csv'
df_features_fp1 = pd.read_csv(path_training+file_psd_features_fp1)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# **Brief Summary about the Participants Selected**

# %%
df_participants_selected
# Out:
#    participant_id  Gender  Age  Group  MMSE  time_max  points  sfreq   flag
# 0         sub-001       0   57      0    16   599.798  299900  500.0   True
# 1         sub-002       0   78      0    22   793.098  396550  500.0   True
# 2         sub-003       1   70      0    14   306.098  153050  500.0  False
# 3         sub-004       0   67      0    20   706.098  353050  500.0   True
# 4         sub-005       1   70      0    22   804.098  402050  500.0   True
# ..            ...     ...  ...    ...   ...       ...     ...    ...    ...
# 83        sub-084       0   71      1    24   652.098  326050  500.0   True
# 84        sub-085       1   64      1    26   560.058  280030  500.0   True
# 85        sub-086       1   49      1    26   578.798  289400  500.0   True
# 86        sub-087       1   73      1    24   602.758  301380  500.0   True
# 87        sub-088       1   55      1    24   784.698  392350  500.0   True
#
# [88 rows x 9 columns]

# %% [markdown]
# Remove Participants not flagged:\
#     - Participants with Healthy Control\
#     - Participants with maximum recorded time less than 540 seconds\
#     - Balancing classes to 22 samples for each group (Alzheimer Disease and Frototemporal Dementia)

# %%
df_participants_selected = df_participants_selected[df_participants_selected['flag']==True].reset_index(drop=True)
df_participants_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   participant_id  44 non-null     object
#  1   Gender          44 non-null     int64
#  2   Age             44 non-null     int64
#  3   Group           44 non-null     int64
#  4   MMSE            44 non-null     int64
#  5   time_max        44 non-null     float64
#  6   points          44 non-null     int64
#  7   sfreq           44 non-null     float64
#  8   flag            44 non-null     bool
# dtypes: bool(1), float64(2), int64(5), object(1)
# memory usage: 2.9+ KB

# %%
df_participants_selected.groupby('Group')['participant_id'].count()
# Out:
# Group
# 0    22
# 1    22
# Name: participant_id, dtype: int64

# %% [markdown]
# **Features Extracted using PSD Method from MNE for All the Channels**

# %%
eeg_mne.Dataset_Features_Summary(df_features_all)
# Out:
# Total Features: 6274
# Windows: 11 -> ['w0', 'w1', 'w10', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9']
# Channels: 19 -> ['F4', 'Fz', 'Cz', 'P3', 'T6', 'Pz', 'F7', 'T4', 'C3', 'T5', 'F3', 'T3', 'Fp1', 'C4', 'F8', 'Fp2', 'P4', 'O2', 'O1']
# Frequency Bands: 5 -> ['alpha', 'gamma', 'theta', 'beta', 'delta']
# Features: 6 -> ['total power', 'peak to peak', 'std dev', 'relative power', 'average power', 'spectral entropy']

# %% [markdown]
# **Features Extracted using PSD Method from MNE for the _FP1_ Channel**

# %%
eeg_mne.Dataset_Features_Summary(df_features_fp1)
# Out:
# Total Features: 334
# Windows: 11 -> ['w0', 'w1', 'w10', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9']
# Channels: 1 -> ['Fp1']
# Frequency Bands: 5 -> ['alpha', 'gamma', 'theta', 'beta', 'delta']
# Features: 6 -> ['total power', 'peak to peak', 'std dev', 'relative power', 'average power', 'spectral entropy']

# %% [markdown]
# ## Preselect only the Total Power Features

# %%
freq_bands_filtered = ['alpha','theta']
features_filtered = []

# %%
df_features_all = eeg_mne.filter_Features(df_features_all, freq_bands_filtered, features_filtered)
eeg_mne.Dataset_Features_Summary(df_features_all)
# Out:
# Number of Features Returned: 2512
# Total Features: 2512
# Windows: 11 -> ['w0', 'w1', 'w10', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9']
# Channels: 19 -> ['F4', 'Fz', 'Cz', 'P3', 'T6', 'Pz', 'F7', 'T4', 'C3', 'T5', 'F3', 'T3', 'Fp1', 'C4', 'F8', 'Fp2', 'P4', 'O2', 'O1']
# Frequency Bands: 2 -> ['alpha', 'theta']
# Features: 6 -> ['total power', 'peak to peak', 'std dev', 'relative power', 'average power', 'spectral entropy']

# %%
df_features_fp1 = eeg_mne.filter_Features(df_features_fp1, freq_bands_filtered, features_filtered)
eeg_mne.Dataset_Features_Summary(df_features_fp1)
# Out:
# Number of Features Returned: 136
# Total Features: 136
# Windows: 11 -> ['w0', 'w1', 'w10', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9']
# Channels: 1 -> ['Fp1']
# Frequency Bands: 2 -> ['alpha', 'theta']
# Features: 6 -> ['total power', 'peak to peak', 'std dev', 'relative power', 'average power', 'spectral entropy']

# %% [markdown]
# ## Predictions with Cross-Validation

# %% [markdown]
# ### All Channels

# %%
df_results_cv_allch = eeg_mne.eeg_classifier_cv(df=df_features_all, feature_id='participant_id', target='Group', feature_extraction='PSD', channels='All')
df_results_cv_allch.head(10)
# Out:
# Running: Support Vector
# Running: Random Forest
# Running: XGBoost
# Running: LigthGBM
# Running: AdaBoost
#   feature_extraction channels      classifier        cross-validation  \
# 0                PSD      All  Support Vector                   KFold
# 1                PSD      All  Support Vector                   KFold
# 2                PSD      All  Support Vector                   KFold
# 3                PSD      All  Support Vector         StratifiedKFold
# 4                PSD      All  Support Vector         StratifiedKFold
# 5                PSD      All  Support Vector         StratifiedKFold
# 6                PSD      All  Support Vector  StratifiedShuffleSplit
# 7                PSD      All  Support Vector  StratifiedShuffleSplit
# 8                PSD      All  Support Vector  StratifiedShuffleSplit
# 9                PSD      All   Random Forest                   KFold
#
#      feature-selection  accuracy  f1_score       AUC
# 0                anova  0.366667  0.312902  0.386667
# 1  mutual_info_classif  0.411111  0.289744  0.500000
# 2                 chi2  0.461111  0.369744  0.550000
# 3                anova  0.500000  0.481320  0.505000
# 4  mutual_info_classif  0.522222  0.406282  0.555000
# 5                 chi2  0.480556  0.358881  0.525000
# 6                anova  0.444444  0.374026  0.435000
# 7  mutual_info_classif  0.444444  0.306044  0.475000
# 8                 chi2  0.444444  0.307692  0.500000
# 9                anova  0.458333  0.395348  0.490000

# %% [markdown]
# Show the Top 20 results

# %%
df_results_cv_allch.sort_values('AUC',ascending=False).head(20)
# Out:
#    feature_extraction channels      classifier        cross-validation  \
# 24                PSD      All         XGBoost  StratifiedShuffleSplit
# 12                PSD      All   Random Forest         StratifiedKFold
# 4                 PSD      All  Support Vector         StratifiedKFold
# 21                PSD      All         XGBoost         StratifiedKFold
# 2                 PSD      All  Support Vector                   KFold
# 14                PSD      All   Random Forest         StratifiedKFold
# 20                PSD      All         XGBoost                   KFold
# 5                 PSD      All  Support Vector         StratifiedKFold
# 23                PSD      All         XGBoost         StratifiedKFold
# 39                PSD      All        AdaBoost         StratifiedKFold
# 44                PSD      All        AdaBoost  StratifiedShuffleSplit
# 41                PSD      All        AdaBoost         StratifiedKFold
# 38                PSD      All        AdaBoost                   KFold
# 3                 PSD      All  Support Vector         StratifiedKFold
# 1                 PSD      All  Support Vector                   KFold
# 28                PSD      All        LigthGBM                   KFold
# 30                PSD      All        LigthGBM         StratifiedKFold
# 27                PSD      All        LigthGBM                   KFold
# 31                PSD      All        LigthGBM         StratifiedKFold
# 32                PSD      All        LigthGBM         StratifiedKFold
#
#       feature-selection  accuracy  f1_score    AUC
# 24                anova  0.600000  0.564612  0.585
# 12                anova  0.544444  0.479614  0.565
# 4   mutual_info_classif  0.522222  0.406282  0.555
# 21                anova  0.544444  0.540000  0.550
# 2                  chi2  0.461111  0.369744  0.550
# 14                 chi2  0.544444  0.523030  0.545
# 20                 chi2  0.569444  0.499968  0.530
# 5                  chi2  0.480556  0.358881  0.525
# 23                 chi2  0.522222  0.504701  0.520
# 39                anova  0.500000  0.435169  0.520
# 44                 chi2  0.511111  0.476234  0.515
# 41                 chi2  0.500000  0.486234  0.510
# 38                 chi2  0.502778  0.483680  0.510
# 3                 anova  0.500000  0.481320  0.505
# 1   mutual_info_classif  0.411111  0.289744  0.500
# 28  mutual_info_classif  0.411111  0.289744  0.500
# 30                anova  0.455556  0.312821  0.500
# 27                anova  0.411111  0.289744  0.500
# 31  mutual_info_classif  0.455556  0.312821  0.500
# 32                 chi2  0.455556  0.312821  0.500

# %% [markdown]
# ### FP1 Channel

# %%
df_results_cv_fp1 = eeg_mne.eeg_classifier_cv(df=df_features_fp1, feature_id='participant_id', target='Group', feature_extraction='PSD', channels='Fp1')
df_results_cv_fp1.head(10)
# Out:
# Running: Support Vector
# Running: Random Forest
# Running: XGBoost
# Running: LigthGBM
# Running: AdaBoost
#   feature_extraction channels      classifier        cross-validation  \
# 0                PSD      Fp1  Support Vector                   KFold
# 1                PSD      Fp1  Support Vector                   KFold
# 2                PSD      Fp1  Support Vector                   KFold
# 3                PSD      Fp1  Support Vector         StratifiedKFold
# 4                PSD      Fp1  Support Vector         StratifiedKFold
# 5                PSD      Fp1  Support Vector         StratifiedKFold
# 6                PSD      Fp1  Support Vector  StratifiedShuffleSplit
# 7                PSD      Fp1  Support Vector  StratifiedShuffleSplit
# 8                PSD      Fp1  Support Vector  StratifiedShuffleSplit
# 9                PSD      Fp1   Random Forest                   KFold
#
#      feature-selection  accuracy  f1_score       AUC
# 0                anova  0.461111  0.369744  0.550000
# 1  mutual_info_classif  0.455556  0.339744  0.500000
# 2                 chi2  0.461111  0.369744  0.550000
# 3                anova  0.480556  0.358881  0.525000
# 4  mutual_info_classif  0.455556  0.392094  0.465000
# 5                 chi2  0.480556  0.358881  0.525000
# 6                anova  0.466667  0.356154  0.515000
# 7  mutual_info_classif  0.422222  0.320979  0.470000
# 8                 chi2  0.444444  0.307692  0.500000
# 9                anova  0.361111  0.327561  0.378333

# %%
df_results_cv_fp1.sort_values('AUC',ascending=False).head(20)
# Out:
#    feature_extraction channels      classifier        cross-validation  \
# 26                PSD      Fp1         XGBoost  StratifiedShuffleSplit
# 0                 PSD      Fp1  Support Vector                   KFold
# 17                PSD      Fp1   Random Forest  StratifiedShuffleSplit
# 2                 PSD      Fp1  Support Vector                   KFold
# 38                PSD      Fp1        AdaBoost                   KFold
# 14                PSD      Fp1   Random Forest         StratifiedKFold
# 23                PSD      Fp1         XGBoost         StratifiedKFold
# 24                PSD      Fp1         XGBoost  StratifiedShuffleSplit
# 11                PSD      Fp1   Random Forest                   KFold
# 3                 PSD      Fp1  Support Vector         StratifiedKFold
# 5                 PSD      Fp1  Support Vector         StratifiedKFold
# 6                 PSD      Fp1  Support Vector  StratifiedShuffleSplit
# 18                PSD      Fp1         XGBoost                   KFold
# 41                PSD      Fp1        AdaBoost         StratifiedKFold
# 25                PSD      Fp1         XGBoost  StratifiedShuffleSplit
# 21                PSD      Fp1         XGBoost         StratifiedKFold
# 44                PSD      Fp1        AdaBoost  StratifiedShuffleSplit
# 20                PSD      Fp1         XGBoost                   KFold
# 31                PSD      Fp1        LigthGBM         StratifiedKFold
# 27                PSD      Fp1        LigthGBM                   KFold
#
#       feature-selection  accuracy  f1_score       AUC
# 26                 chi2  0.600000  0.559997  0.605000
# 0                 anova  0.461111  0.369744  0.550000
# 17                 chi2  0.555556  0.528799  0.550000
# 2                  chi2  0.461111  0.369744  0.550000
# 38                 chi2  0.541667  0.502541  0.545000
# 14                 chi2  0.522222  0.455211  0.545000
# 23                 chi2  0.522222  0.503456  0.540000
# 24                anova  0.511111  0.477006  0.530000
# 11                 chi2  0.497222  0.473434  0.530000
# 3                 anova  0.480556  0.358881  0.525000
# 5                  chi2  0.480556  0.358881  0.525000
# 6                 anova  0.466667  0.356154  0.515000
# 18                anova  0.472222  0.455339  0.513333
# 41                 chi2  0.497222  0.486133  0.510000
# 25  mutual_info_classif  0.511111  0.498456  0.510000
# 21                anova  0.500000  0.477814  0.505000
# 44                 chi2  0.511111  0.502092  0.505000
# 20                 chi2  0.497222  0.469416  0.503333
# 31  mutual_info_classif  0.455556  0.312821  0.500000
# 27                anova  0.411111  0.289744  0.500000

# %% [markdown]
# Best performance from each Classifier for the two approaches (All Channels and FP1 Channel)

# %%
df_results_cv = pd.concat([df_results_cv_allch, df_results_cv_fp1], ignore_index=True)
df_results_cv['feature_extraction'] = 'PSD only Total Power'
df_results_cv_sorted = df_results_cv.sort_values('AUC',ascending=False)
df_results_cv_sorted.groupby(['channels']).head(5)
# Out:
#       feature_extraction channels      classifier        cross-validation  \
# 71  PSD only Total Power      Fp1         XGBoost  StratifiedShuffleSplit
# 24  PSD only Total Power      All         XGBoost  StratifiedShuffleSplit
# 12  PSD only Total Power      All   Random Forest         StratifiedKFold
# 4   PSD only Total Power      All  Support Vector         StratifiedKFold
# 45  PSD only Total Power      Fp1  Support Vector                   KFold
# 2   PSD only Total Power      All  Support Vector                   KFold
# 47  PSD only Total Power      Fp1  Support Vector                   KFold
# 21  PSD only Total Power      All         XGBoost         StratifiedKFold
# 62  PSD only Total Power      Fp1   Random Forest  StratifiedShuffleSplit
# 83  PSD only Total Power      Fp1        AdaBoost                   KFold
#
#       feature-selection  accuracy  f1_score    AUC
# 71                 chi2  0.600000  0.559997  0.605
# 24                anova  0.600000  0.564612  0.585
# 12                anova  0.544444  0.479614  0.565
# 4   mutual_info_classif  0.522222  0.406282  0.555
# 45                anova  0.461111  0.369744  0.550
# 2                  chi2  0.461111  0.369744  0.550
# 47                 chi2  0.461111  0.369744  0.550
# 21                anova  0.544444  0.540000  0.550
# 62                 chi2  0.555556  0.528799  0.550
# 83                 chi2  0.541667  0.502541  0.545

# %% [markdown]
# ## Save Results

# %%
file_results_cv = 'Results PSD Alpha-Theta - Cross-Validation.csv'
df_results_cv.to_csv(path_training+file_results_cv)
